# %% [markdown]
# # Quick Algorithm - ML Pipeline Challenge
#
# https://gitlab.com/qa-public/qa-streaming-pipeline-challenge#user-interaction

# %% [markdown]
# ## Dataframe Creation
#
# ### Importing necessary modules

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Finding the 'end-point' in database & Framing the Data

# %% [markdown]
# The database is packed with data, and thus it is necessary for the code of figure out where the list of employees end. Instead of doing the whole entire project in a function, it is better practice to compartamentalize the flow, for future database updates, etc.
#
# I will not use any fancy coding here, since it is a mere environmental setup.
#
# For a shorter runtime, I will intentionally increment the 'search grid' by 1000, then manually check if this is the border. In the real-application, one would be better off with a increment of 1, whilst having more time-optimized code.

# %%
def find(port):
    if type(port) != str:
        raise Exception('port must be an url expresseed with a string, page unspecified.')

    counter = 0
    
    while requests.get(port + '?page={}'.format(counter)).json() != []:
        counter += 1000

    return counter

# %%
find('http://localhost:5000/api/v1/data')
# Out:
# 100000

# %% [markdown]
# We have found that at the data ends somewhere in between 99000 and 100000. Indeed, the limit here was at a 99999-100000.

# %% [markdown]
# Now we build a function to retrieve the data available from the database, to create a long list of JSON data, which then we will convert to pandas dataframe, in order to make manipulations easier. The function is designed to obtain the data until an arbitrary page, but in the case we want them all, so we will select 100000 as our limit. Again, this piece of code prioritizes its simpleness and intuitiveness over runtime, and since this has to go through 100000 loops with appending, it will take some time to complete.

# %%
def obtain_list(port, limit):
    if type(port) != str:
        raise Exception('port must be an url expresseed with a string, page unspecified.')

    if type(limit) != int or limit < 0:
        raise Exception('limit has to be a positive integer.')
    
    data = []
        
    for i in range(limit):
        data.append(requests.get(port + '?page={}'.format(i)).json())
    
    return data

# %% [markdown]
# In the creation of this listing, we have a multi-dimensional list, specifically having (# of pages, 10) . But we want (1, # ofpages * 10), thus we resort to a very simple method of flattening the list. convering to nparray then flattening should make no difference to this method.

# %%
dataset = sum(obtain_list('http://localhost:5000/api/v1/data',100), [])

dataset
# Out:
# [{'competence': 2.1561929505672226,
#   'id': 0,
#   'network_ability': -0.13850255563080713,
#   'promoted': 1},
#  {'competence': 0.1503209340782082,
#   'id': 1,
#   'network_ability': 0.6802618180031226,
#   'promoted': 0},
#  {'competence': 0.439139006444416,
#   'id': 2,
#   'network_ability': 1.0768018489787832,
#   'promoted': 1},
#  {'competence': -0.5154817414166092,
#   'id': 3,
#   'network_ability': -0.9299164880823638,
#   'promoted': 0},
#  {'competence': -0.7928276291200661,
#   'id': 4,
#   'network_ability': 0.23833774107081732,
#   'promoted': 0},
#  {'competence': -0.026650045224544557,
#   'id': 5,
#   'network_ability': -0.6416174585974274,
#   'promoted': 0},
#  {'competence': -0.480352986575169,
#   'id': 6,
#   'network_ability': 1.5730391776913912,
#   'promoted': 1},
#  {'competence': 0.37663500837867614,
#   'id': 7,
#   'network_ability': -1.118131621983561,
#   'promoted': 0},
#  {'competence': 0.34780430681736957,
#   'id': 8,
#   'network_ability': 0.5897098603358912,
#   'promoted': 0},
#  {'competence': 1.3518261083995122,
#   'id': 9,
#   'network_ability': 0.666059370776436,
#   'promoted': 1},
#  {'competence': 0.6855610037393558,
#   'id': 10,
#   'network_ability': -0.7281498777445632,
#   'promoted': 0},
#  {'competence': 0.7826266229364608,
#   'id': 11,
#   'network_ability': -0.2984654985454323,
#   'promoted': 0},
#  {'competence': -0.8848909298372895,
#   'id': 12,
#   'network_ability': -0.15108502591379444,
#   'promoted': 0},
#  {'competence': 1.260707270046886,
#   'id': 13,
#   'network_ability': -0.5478639973028793,
#   'promoted': 1},
#  {'competence': -0.12251544094017544,
#   'id': 14,
#   'network_ability': -1.6039328302796794,
#   'promoted': 0},
#  {'competence': -1.2582439945017887,
#   'id': 15,
#   'network_ability': 0.7546333487546836,
#   'promoted': 0},
#  {'competence': 0.684312229254339,
#   'id': 16,
#   'network_ability': -0.0904031182326621,
#   'promoted': 0},
#  {'competence': 1.8340120640106803,
#   'id': 17,
#   'network_ability': 0.5392433562055757,
#   'promoted': 1},
#  {'competence': -0.00354008668573061,
#   'id': 18,
#   'network_ability': -1.9111559638217608,
#   'promoted': 0},
#  {'competence': 0.17610750428141148,
#   'id': 19,
#   'network_ability': 0.9656268947448157,
#   'promoted': 0},
#  {'competence': 0.2212924276975411,
#   'id': 20,
#   'network_ability': -1.597120646135752,
#   'promoted': 0},
#  {'competence': 0.2911649577077878,
#   'id': 21,
#   'network_ability': 0.03249449701607117,
#   'promoted': 0},
#  {'competence': -0.9286008183234993,
#   'id': 22,
#   'network_ability': 0.5072383945069813,
#   'promoted': 0},
#  {'competence': -0.45065498611647914,
#   'id': 23,
#   'network_ability': -0.2032847896453733,
#   'promoted': 0},
#  {'competence': 0.8054250030715739,
#   'id': 24,
#   'network_ability': -0.7710184462402463,
#   'promoted': 0},
#  {'competence': -0.7130147912445459,
#   'id': 25,
#   'network_ability': -0.3693938976004073,
#   'promoted': 0},
#  {'competence': -0.16550115621813052,
#   'id': 26,
#   'network_ability': -0.21097682021818318,
#   'promoted': 0},
#  {'competence': 0.894957510078755,
#   'id': 27,
#   'network_ability': 0.5178883568516306,
#   'promoted': 0},
#  {'competence': -0.46479567994950965,
#   'id': 28,
#   'network_ability': 1.5260775687438521,
#   'promoted': 1},
#  {'competence': 2.179148165916739,
#   'id': 29,
#   'network_ability': 0.6415088314161381,
#   'promoted': 1},
#  {'competence': 0.4535070463768239,
#   'id': 30,
#   'network_ability': 1.8141915340483656,
#   'promoted': 1},
#  {'competence': -1.0464611304835045,
#   'id': 31,
#   'network_ability': 0.2895766781367294,
#   'promoted': 0},
#  {'competence': 0.9513423680188527,
#   'id': 32,
#   'network_ability': -0.5949433198010133,
#   'promoted': 0},
#  {'competence': -0.37580673130528436,
#   'id': 33,
#   'network_ability': -0.7046085125248304,
#   'promoted': 0},
#  {'competence': -1.0605860749454532,
#   'id': 34,
#   'network_ability': 1.3857952630398036,
#   'promoted': 1},
#  {'competence': -0.4454061230520579,
#   'id': 35,
#   'network_ability': 0.7310434945628093,
#   'promoted': 0},
#  {'competence': -0.7965396692251228,
#   'id': 36,
#   'network_ability': 0.840587955118403,
#   'promoted': 0},
#  {'competence': -0.4863921484005,
#   'id': 37,
#   'network_ability': -0.2520545541042685,
#   'promoted': 0},
#  {'competence': 1.2586415475602006,
#   'id': 38,
#   'network_ability': 1.3510631088685154,
#   'promoted': 1},
#  {'competence': 1.0266259662717638,
#   'id': 39,
#   'network_ability': -0.4219135823969711,
#   'promoted': 1},
#  {'competence': 0.8154619606368156,
#   'id': 40,
#   'network_ability': 0.33632981721375255,
#   'promoted': 0},
#  {'competence': -0.35440637242862005,
#   'id': 41,
#   'network_ability': 0.23628728466535687,
#   'promoted': 0},
#  {'competence': -1.8694794788559481,
#   'id': 42,
#   'network_ability': -0.0801127646936423,
#   'promoted': 0},
#  {'competence': 0.9618610667886635,
#   'id': 43,
#   'network_ability': 1.2601704195232457,
#   'promoted': 1},
#  {'competence': -0.7751129042912428,
#   'id': 44,
#   'network_ability': 0.9657194884442974,
#   'promoted': 0},
#  {'competence': -0.20098397481168429,
#   'id': 45,
#   'network_ability': 0.7141929940940409,
#   'promoted': 0},
#  {'competence': -2.088290388443251,
#   'id': 46,
#   'network_ability': -2.114582937036355,
#   'promoted': 0},
#  {'competence': 2.0231309637237618,
#   'id': 47,
#   'network_ability': -1.6490893802602598,
#   'promoted': 1},
#  {'competence': -0.18216329685077925,
#   'id': 48,
#   'network_ability': 2.475765562150239,
#   'promoted': 1},
#  {'competence': -0.6760812070329343,
#   'id': 49,
#   'network_ability': -1.6107330933907014,
#   'promoted': 0},
#  {'competence': 0.09600366794031205,
#   'id': 50,
#   'network_ability': 1.1598000475959214,
#   'promoted': 1},
#  {'competence': -1.0647215814875062,
#   'id': 51,
#   'network_ability': -0.961290480711976,
#   'promoted': 0},
#  {'competence': -1.7320027206060855,
#   'id': 52,
#   'network_ability': -0.10216571536920481,
#   'promoted': 0},
#  {'competence': 0.6788089759114968,
#   'id': 53,
#   'network_ability': -0.49916712543869024,
#   'promoted': 0},
#  {'competence': 1.0780293029692298,
#   'id': 54,
#   'network_ability': 0.1866263482946334,
#   'promoted': 1},
#  {'competence': -0.6401339036494116,
#   'id': 55,
#   'network_ability': -0.8433419197264271,
#   'promoted': 0},
#  {'competence': 0.2815491360002941,
#   'id': 56,
#   'network_ability': -0.0969095646952793,
#   'promoted': 0},
#  {'competence': 0.2732808050068915,
#   'id': 57,
#   'network_ability': -0.6924298471845974,
#   'promoted': 0},
#  {'competence': -0.578034748583269,
#   'id': 58,
#   'network_ability': -0.8114232216527829,
#   'promoted': 0},
#  {'competence': -0.6041731235514346,
#   'id': 59,
#   'network_ability': -0.01113541655752439,
#   'promoted': 0},
#  {'competence': 0.9532054188804204,
#   'id': 60,
#   'network_ability': 0.5017952046679864,
#   'promoted': 0},
#  {'competence': -0.06121905716034405,
#   'id': 61,
#   'network_ability': 1.7518065604465605,
#   'promoted': 1},
#  {'competence': 1.3565572071854242,
#   'id': 62,
#   'network_ability': -1.948412485287265,
#   'promoted': 1},
#  {'competence': 1.000117447701872,
#   'id': 63,
#   'network_ability': -0.13265216978724376,
#   'promoted': 1},
#  {'competence': -0.1358686496790549,
#   'id': 64,
#   'network_ability': 0.990774823244619,
#   'promoted': 0},
#  {'competence': 1.056454546019203,
#   'id': 65,
#   'network_ability': 0.6499632287865864,
#   'promoted': 1},
#  {'competence': 0.017201231164912224,
#   'id': 66,
#   'network_ability': -0.3621352848205279,
#   'promoted': 0},
#  {'competence': 2.245818940302879,
#   'id': 67,
#   'network_ability': 0.6242106834933219,
#   'promoted': 1},
#  {'competence': 0.4685669168978039,
#   'id': 68,
#   'network_ability': -0.030003062165753065,
#   'promoted': 1},
#  {'competence': 0.13412200114210512,
#   'id': 69,
#   'network_ability': -2.014583817898678,
#   'promoted': 0},
#  {'competence': 1.6054434193584937,
#   'id': 70,
#   'network_ability': -0.4768129247131349,
#   'promoted': 1},
#  {'competence': -0.3099347581936113,
#   'id': 71,
#   'network_ability': 0.3037036125548946,
#   'promoted': 0},
#  {'competence': -0.8978905326296388,
#   'id': 72,
#   'network_ability': 0.7093324599716488,
#   'promoted': 0},
#  {'competence': 1.0415825232009788,
#   'id': 73,
#   'network_ability': 0.4380180967467283,
#   'promoted': 1},
#  {'competence': -0.6795074446875253,
#   'id': 74,
#   'network_ability': -0.7011323688920511,
#   'promoted': 0},
#  {'competence': 0.5621697103181859,
#   'id': 75,
#   'network_ability': 0.8895498928057259,
#   'promoted': 0},
#  {'competence': 1.2436806413769315,
#   'id': 76,
#   'network_ability': -0.3088061594612132,
#   'promoted': 1},
#  {'competence': 1.3750213990482907,
#   'id': 77,
#   'network_ability': -1.237160658703776,
#   'promoted': 1},
#  {'competence': -0.5929240680802063,
#   'id': 78,
#   'network_ability': 1.8627051535385346,
#   'promoted': 1},
#  {'competence': 1.114948069722795,
#   'id': 79,
#   'network_ability': 1.8491224677608642,
#   'promoted': 1},
#  {'competence': 0.8297950120441955,
#   'id': 80,
#   'network_ability': 0.29411023093528943,
#   'promoted': 0},
#  {'competence': 1.2995602559631902,
#   'id': 81,
#   'network_ability': -0.3728550694592489,
#   'promoted': 1},
#  {'competence': -0.7661401370367079,
#   'id': 82,
#   'network_ability': 0.9618332769442778,
#   'promoted': 0},
#  {'competence': -1.7539837058941243,
#   'id': 83,
#   'network_ability': 1.1650100758425401,
#   'promoted': 0},
#  {'competence': 1.3586054093184816,
#   'id': 84,
#   'network_ability': -2.0966123148171585,
#   'promoted': 0},
#  {'competence': 0.3560811742216031,
#   'id': 85,
#   'network_ability': 0.5927247356546875,
#   'promoted': 0},
#  {'competence': -0.8737354155914445,
#   'id': 86,
#   'network_ability': 0.74556455865371,
#   'promoted': 0},
#  {'competence': 0.8074858692786835,
#   'id': 87,
#   'network_ability': 1.9287902154404772,
#   'promoted': 1},
#  {'competence': -0.33558669628859333,
#   'id': 88,
#   'network_ability': 0.7199400619017091,
#   'promoted': 0},
#  {'competence': 1.2323526185771012,
#   'id': 89,
#   'network_ability': 0.9993604170859596,
#   'promoted': 1},
#  {'competence': 0.9280252209531527,
#   'id': 90,
#   'network_ability': -0.16065997531990794,
#   'promoted': 0},
#  {'competence': -0.13084828583760882,
#   'id': 91,
#   'network_ability': 1.4974816308735648,
#   'promoted': 1},
#  {'competence': 0.17736149298627282,
#   'id': 92,
#   'network_ability': 1.460075570813872,
#   'promoted': 1},
#  {'competence': -0.2630285614934988,
#   'id': 93,
#   'network_ability': -1.4555204500581367,
#   'promoted': 1},
#  {'competence': -0.22884768772328576,
#   'id': 94,
#   'network_ability': -0.16713302386396767,
#   'promoted': 0},
#  {'competence': -0.25947284658151454,
#   'id': 95,
#   'network_ability': 0.33326795481825844,
#   'promoted': 0},
#  {'competence': 0.04942987553920971,
#   'id': 96,
#   'network_ability': -0.3490779398919549,
#   'promoted': 0},
#  {'competence': -1.0344905190199245,
#   'id': 97,
#   'network_ability': 1.1895073690902298,
#   'promoted': 1},
#  {'competence': 1.2716992791521262,
#   'id': 98,
#   'network_ability': 1.8488723701048697,
#   'promoted': 1},
#  {'competence': -0.13466534882481945,
#   'id': 99,
#   'network_ability': -0.43911391611850076,
#   'promoted': 0},
#  {'competence': -0.4940213038841402,
#   'id': 100,
#   'network_ability': 0.3304911223188995,
#   'promoted': 0},
#  {'competence': -0.7427437202776698,
#   'id': 101,
#   'network_ability': 1.9701869391266098,
#   'promoted': 1},
#  {'competence': 0.426507829024355,
#   'id': 102,
#   'network_ability': 0.12960327263368884,
#   'promoted': 0},
#  {'competence': 2.7640933444451252,
#   'id': 103,
#   'network_ability': 0.01412911739699015,
#   'promoted': 1},
#  {'competence': 0.04648999140326052,
#   'id': 104,
#   'network_ability': 0.6243407912366867,
#   'promoted': 0},
#  {'competence': -0.2638207690922454,
#   'id': 105,
#   'network_ability': 0.19541073256105937,
#   'promoted': 1},
#  {'competence': -0.08208160922714074,
#   'id': 106,
#   'network_ability': -0.0025057368424028074,
#   'promoted': 0},
#  {'competence': 0.10286743051401745,
#   'id': 107,
#   'network_ability': 0.6537907599560897,
#   'promoted': 0},
#  {'competence': 1.1605778144443262,
#   'id': 108,
#   'network_ability': 0.7243084501232645,
#   'promoted': 1},
#  {'competence': -0.04830030447998946,
#   'id': 109,
#   'network_ability': 1.5614395697353154,
#   'promoted': 1},
#  {'competence': 0.4839936232254609,
#   'id': 110,
#   'network_ability': 0.18206421297383038,
#   'promoted': 0},
#  {'competence': 0.12910640492944916,
#   'id': 111,
#   'network_ability': 0.801571932261818,
#   'promoted': 0},
#  {'competence': -0.5126427067564167,
#   'id': 112,
#   'network_ability': -2.5101407936887563,
#   'promoted': 0},
#  {'competence': -0.24465624858231336,
#   'id': 113,
#   'network_ability': 0.09475859571429084,
#   'promoted': 0},
#  {'competence': -0.39080554661705474,
#   'id': 114,
#   'network_ability': 2.186667611913442,
#   'promoted': 1},
#  {'competence': -0.2029579430873626,
#   'id': 115,
#   'network_ability': -1.2040121643850237,
#   'promoted': 0},
#  {'competence': 0.5843269441044983,
#   'id': 116,
#   'network_ability': -2.8641502943728403,
#   'promoted': 0},
#  {'competence': 1.9110525202117499,
#   'id': 117,
#   'network_ability': -0.49089414698244327,
#   'promoted': 1},
#  {'competence': -0.32621521855871227,
#   'id': 118,
#   'network_ability': -0.7118363192827354,
#   'promoted': 0},
#  {'competence': 0.6117352842353438,
#   'id': 119,
#   'network_ability': 0.04160027041390332,
#   'promoted': 0},
#  {'competence': -1.2770017671283371,
#   'id': 120,
#   'network_ability': 0.9188603976681895,
#   'promoted': 0},
#  {'competence': -0.11733364282279535,
#   'id': 121,
#   'network_ability': -0.6816609218797894,
#   'promoted': 0},
#  {'competence': -1.6942914615418567,
#   'id': 122,
#   'network_ability': -1.1693261398777561,
#   'promoted': 0},
#  {'competence': 0.05421363587086288,
#   'id': 123,
#   'network_ability': -0.09258873307732894,
#   'promoted': 0},
#  {'competence': 0.44075420522421493,
#   'id': 124,
#   'network_ability': -0.2572563179967009,
#   'promoted': 0},
#  {'competence': 0.6419257423651199,
#   'id': 125,
#   'network_ability': -0.5351481929691143,
#   'promoted': 0},
#  {'competence': 1.1450747218348793,
#   'id': 126,
#   'network_ability': -0.7402079184557729,
#   'promoted': 1},
#  {'competence': -0.6382381378253675,
#   'id': 127,
#   'network_ability': 0.5234456323679019,
#   'promoted': 0},
#  {'competence': 0.09193738571294047,
#   'id': 128,
#   'network_ability': -0.2590274166780157,
#   'promoted': 0},
#  {'competence': -1.5125827960607545,
#   'id': 129,
#   'network_ability': -1.4235801701623962,
#   'promoted': 0},
#  {'competence': -0.5560863459482217,
#   'id': 130,
#   'network_ability': -0.6421202495660799,
#   'promoted': 0},
#  {'competence': -0.2938094460283374,
#   'id': 131,
#   'network_ability': 0.07631833077962474,
#   'promoted': 0},
#  {'competence': 0.5221213290010333,
#   'id': 132,
#   'network_ability': 0.43281329915594774,
#   'promoted': 0},
#  {'competence': -0.5276641396504664,
#   'id': 133,
#   'network_ability': -0.9233142673296963,
#   'promoted': 0},
#  {'competence': -0.734061813687702,
#   'id': 134,
#   'network_ability': -0.43268113811340414,
#   'promoted': 0},
#  {'competence': 1.2094349824480237,
#   'id': 135,
#   'network_ability': 0.5641961067501874,
#   'promoted': 1},
#  {'competence': -0.34696639142476665,
#   'id': 136,
#   'network_ability': -0.4986305421297674,
#   'promoted': 0},
#  {'competence': -0.9138959843284087,
#   'id': 137,
#   'network_ability': 0.15977130742312537,
#   'promoted': 0},
#  {'competence': -0.5290011568713145,
#   'id': 138,
#   'network_ability': 1.2110775290655993,
#   'promoted': 1},
#  {'competence': 0.37937246405351555,
#   'id': 139,
#   'network_ability': 1.2405488926933037,
#   'promoted': 1},
#  {'competence': 0.6511769855547416,
#   'id': 140,
#   'network_ability': 0.06982518327383626,
#   'promoted': 0},
#  {'competence': 1.4327125318232006,
#   'id': 141,
#   'network_ability': -0.1998492151420279,
#   'promoted': 1},
#  {'competence': 1.503026131415905,
#   'id': 142,
#   'network_ability': -0.45831144830718684,
#   'promoted': 1},
#  {'competence': 2.423317737600607,
#   'id': 143,
#   'network_ability': 0.06425505170718555,
#   'promoted': 1},
#  {'competence': 0.6779129875040038,
#   'id': 144,
#   'network_ability': -0.8827205472733687,
#   'promoted': 0},
#  {'competence': 0.48397042421652336,
#   'id': 145,
#   'network_ability': 0.6805278169417038,
#   'promoted': 0},
#  {'competence': 1.3220499474958527,
#   'id': 146,
#   'network_ability': -1.0723021404934512,
#   'promoted': 1},
#  {'competence': -1.9658929758800756,
#   'id': 147,
#   'network_ability': -0.3365211420929368,
#   'promoted': 0},
#  {'competence': -0.6966156438943218,
#   'id': 148,
#   'network_ability': -0.6036851330606485,
#   'promoted': 1},
#  {'competence': 1.4252744056031408,
#   'id': 149,
#   'network_ability': -1.0047256897294143,
#   'promoted': 1},
#  {'competence': -0.15064275858999132,
#   'id': 150,
#   'network_ability': -1.2091891149563903,
#   'promoted': 0},
#  {'competence': -0.6783905767193434,
#   'id': 151,
#   'network_ability': 0.5450151296072404,
#   'promoted': 0},
#  {'competence': 0.39306202534369383,
#   'id': 152,
#   'network_ability': -0.043184986003732384,
#   'promoted': 0},
#  {'competence': 1.2640686468805384,
#   'id': 153,
#   'network_ability': -0.3676485573898726,
#   'promoted': 1},
#  {'competence': 1.3646586470430104,
#   'id': 154,
#   'network_ability': 2.8782419482217168,
#   'promoted': 1},
#  {'competence': 0.7310639058636093,
#   'id': 155,
#   'network_ability': 1.044876498172225,
#   'promoted': 1},
#  {'competence': -1.020529617596063,
#   'id': 156,
#   'network_ability': 1.0870519228805486,
#   'promoted': 1},
#  {'competence': 0.5916565958506096,
#   'id': 157,
#   'network_ability': -1.0841306298143625,
#   'promoted': 0},
#  {'competence': 2.4970858829694857,
#   'id': 158,
#   'network_ability': 1.2819958068694317,
#   'promoted': 1},
#  {'competence': -1.1174769107378943,
#   'id': 159,
#   'network_ability': -0.46117824465425084,
#   'promoted': 0},
#  {'competence': 2.1086638706282574,
#   'id': 160,
#   'network_ability': 1.412719269918225,
#   'promoted': 1},
#  {'competence': -0.30705905797571037,
#   'id': 161,
#   'network_ability': -0.03303923800372438,
#   'promoted': 0},
#  {'competence': 1.291874090615164,
#   'id': 162,
#   'network_ability': -0.7423906872617788,
#   'promoted': 1},
#  {'competence': -0.1386284896337427,
#   'id': 163,
#   'network_ability': 1.5001710580186185,
#   'promoted': 1},
#  {'competence': -0.964120400032542,
#   'id': 164,
#   'network_ability': 0.42180409449741746,
#   'promoted': 0},
#  {'competence': 1.1167142956936011,
#   'id': 165,
#   'network_ability': 0.3431440807054674,
#   'promoted': 1},
#  {'competence': -0.17477696092641232,
#   'id': 166,
#   'network_ability': -0.7185387230687803,
#   'promoted': 0},
#  {'competence': 0.6990650832590366,
#   'id': 167,
#   'network_ability': 0.4605372962562053,
#   'promoted': 0},
#  {'competence': -2.3069849653230636,
#   'id': 168,
#   'network_ability': 0.9204886656638411,
#   'promoted': 0},
#  {'competence': -0.7801458239914038,
#   'id': 169,
#   'network_ability': 0.7607234768260716,
#   'promoted': 0},
#  {'competence': -0.943773432460956,
#   'id': 170,
#   'network_ability': 0.7331681300062595,
#   'promoted': 0},
#  {'competence': -0.18479974456691448,
#   'id': 171,
#   'network_ability': 1.1467476141373203,
#   'promoted': 1},
#  {'competence': -0.7418715037450142,
#   'id': 172,
#   'network_ability': 0.9358989165213392,
#   'promoted': 0},
#  {'competence': -0.039694714304259145,
#   'id': 173,
#   'network_ability': 0.21496862627122743,
#   'promoted': 0},
#  {'competence': -1.3971764311050052,
#   'id': 174,
#   'network_ability': -0.005472223288108818,
#   'promoted': 0},
#  {'competence': 0.4997549777844822,
#   'id': 175,
#   'network_ability': 1.840575316380599,
#   'promoted': 1},
#  {'competence': -0.179854029459592,
#   'id': 176,
#   'network_ability': 0.5383416823272396,
#   'promoted': 0},
#  {'competence': 2.1875862889048086,
#   'id': 177,
#   'network_ability': -1.1341630083622543,
#   'promoted': 1},
#  {'competence': -0.7481831610232665,
#   'id': 178,
#   'network_ability': 0.9586532288314046,
#   'promoted': 0},
#  {'competence': 0.8782763341999323,
#   'id': 179,
#   'network_ability': -0.38337355852167787,
#   'promoted': 0},
#  {'competence': -0.7563824495396787,
#   'id': 180,
#   'network_ability': -0.06339511105446353,
#   'promoted': 0},
#  {'competence': -0.5880738331539321,
#   'id': 181,
#   'network_ability': -1.0647577010911136,
#   'promoted': 0},
#  {'competence': 0.16169534022632848,
#   'id': 182,
#   'network_ability': 0.0697187333592762,
#   'promoted': 0},
#  {'competence': 0.9279064071848143,
#   'id': 183,
#   'network_ability': -0.7145540021921559,
#   'promoted': 0},
#  {'competence': -0.10579754178307706,
#   'id': 184,
#   'network_ability': -0.7296444371789241,
#   'promoted': 0},
#  {'competence': -0.3648702614469942,
#   'id': 185,
#   'network_ability': -0.34227632043486794,
#   'promoted': 0},
#  {'competence': 0.8431702977215176,
#   'id': 186,
#   'network_ability': -0.3222623921185257,
#   'promoted': 0},
#  {'competence': 1.4931341556779623,
#   'id': 187,
#   'network_ability': -0.05696256029816396,
#   'promoted': 1},
#  {'competence': -0.4552168333317778,
#   'id': 188,
#   'network_ability': 0.8012092119642488,
#   'promoted': 0},
#  {'competence': -1.0261187635251654,
#   'id': 189,
#   'network_ability': 1.1102014348890772,
#   'promoted': 1},
#  {'competence': -0.8811300665003434,
#   'id': 190,
#   'network_ability': 0.19612421151090095,
#   'promoted': 0},
#  {'competence': -1.286199013267682,
#   'id': 191,
#   'network_ability': 1.0719432748417759,
#   'promoted': 1},
#  {'competence': -0.3511648448162154,
#   'id': 192,
#   'network_ability': -0.33721710094569673,
#   'promoted': 0},
#  {'competence': -0.6365631217613811,
#   'id': 193,
#   'network_ability': 1.2688243989862933,
#   'promoted': 1},
#  {'competence': 0.5820267210513885,
#   'id': 194,
#   'network_ability': 2.49596313127244,
#   'promoted': 1},
#  {'competence': 1.3037312837402466,
#   'id': 195,
#   'network_ability': -2.3149321418739763,
#   'promoted': 1},
#  {'competence': -0.7288525413928215,
#   'id': 196,
#   'network_ability': 0.4816039514196483,
#   'promoted': 0},
#  {'competence': -0.43406773808227167,
#   'id': 197,
#   'network_ability': -0.15946202927827113,
#   'promoted': 0},
#  {'competence': -0.27133843239631306,
#   'id': 198,
#   'network_ability': -0.43781866736402797,
#   'promoted': 0},
#  {'competence': 0.170217714399855,
#   'id': 199,
#   'network_ability': -1.9693384478356464,
#   'promoted': 0},
#  {'competence': 0.43168447962052886,
#   'id': 200,
#   'network_ability': -0.7584846972260472,
#   'promoted': 0},
#  {'competence': -0.1438879207866024,
#   'id': 201,
#   'network_ability': 0.35765742928686645,
#   'promoted': 0},
#  {'competence': 0.3289634345932151,
#   'id': 202,
#   'network_ability': -1.9636201101577109,
#   'promoted': 1},
#  {'competence': -0.24808026578932887,
#   'id': 203,
#   'network_ability': -0.8096099170426961,
#   'promoted': 0},
#  {'competence': -0.18615712785021257,
#   'id': 204,
#   'network_ability': 0.12277432531712866,
#   'promoted': 0},
#  {'competence': 1.6558853166586183,
#   'id': 205,
#   'network_ability': 0.5627637507697602,
#   'promoted': 1},
#  {'competence': -1.281198135825646,
#   'id': 206,
#   'network_ability': -1.1345482900372386,
#   'promoted': 0},
#  {'competence': -1.2313514240267083,
#   'id': 207,
#   'network_ability': 0.9613859881345289,
#   'promoted': 0},
#  {'competence': -0.8124435482802488,
#   'id': 208,
#   'network_ability': 1.1011275571924186,
#   'promoted': 1},
#  {'competence': -0.559713777793015,
#   'id': 209,
#   'network_ability': -2.2634067427494076,
#   'promoted': 1},
#  {'competence': 0.6872092321138593,
#   'id': 210,
#   'network_ability': -1.796883416022954,
#   'promoted': 0},
#  {'competence': 0.05654125746345762,
#   'id': 211,
#   'network_ability': -1.6966698168798033,
#   'promoted': 0},
#  {'competence': -0.08466631328679528,
#   'id': 212,
#   'network_ability': -0.771457433394949,
#   'promoted': 0},
#  {'competence': 2.0355581193097128,
#   'id': 213,
#   'network_ability': 2.01213141718354,
#   'promoted': 1},
#  {'competence': 0.29731775341626815,
#   'id': 214,
#   'network_ability': 1.0241241809408628,
#   'promoted': 1},
#  {'competence': 0.31062071728823815,
#   'id': 215,
#   'network_ability': 0.22307682510081894,
#   'promoted': 0},
#  {'competence': 0.20993810255458223,
#   'id': 216,
#   'network_ability': -2.107148730519069,
#   'promoted': 0},
#  {'competence': -0.2198846254203569,
#   'id': 217,
#   'network_ability': 2.913258882725183,
#   'promoted': 1},
#  {'competence': -0.9001801194554199,
#   'id': 218,
#   'network_ability': -0.9953109826132321,
#   'promoted': 0},
#  {'competence': 0.5514855521371582,
#   'id': 219,
#   'network_ability': 1.533168453226861,
#   'promoted': 1},
#  {'competence': -0.8392340979571056,
#   'id': 220,
#   'network_ability': 0.4816622735786331,
#   'promoted': 0},
#  {'competence': -0.6183527582104721,
#   'id': 221,
#   'network_ability': -0.8373561476295474,
#   'promoted': 0},
#  {'competence': 0.15763777422700176,
#   'id': 222,
#   'network_ability': -0.316578406030015,
#   'promoted': 0},
#  {'competence': -0.21909626147478828,
#   'id': 223,
#   'network_ability': 0.5970082970666258,
#   'promoted': 0},
#  {'competence': -0.01580383844961079,
#   'id': 224,
#   'network_ability': 1.5705311935423332,
#   'promoted': 1},
#  {'competence': -1.2073218819187659,
#   'id': 225,
#   'network_ability': -2.3757671783607677,
#   'promoted': 0},
#  {'competence': 2.284800683264076,
#   'id': 226,
#   'network_ability': -0.03953028635015731,
#   'promoted': 1},
#  {'competence': -0.08328323560957451,
#   'id': 227,
#   'network_ability': 0.4017256726830558,
#   'promoted': 0},
#  {'competence': 2.1021060930656,
#   'id': 228,
#   'network_ability': -1.0169998630618413,
#   'promoted': 1},
#  {'competence': -0.7796394333684951,
#   'id': 229,
#   'network_ability': 0.7807305080780983,
#   'promoted': 0},
#  {'competence': 0.18731076226669058,
#   'id': 230,
#   'network_ability': 1.3120826259628384,
#   'promoted': 1},
#  {'competence': 0.7785680329481447,
#   'id': 231,
#   'network_ability': -0.7512684916614516,
#   'promoted': 1},
#  {'competence': -0.21330082484409815,
#   'id': 232,
#   'network_ability': 0.6392782405321058,
#   'promoted': 0},
#  {'competence': -0.9070249031230568,
#   'id': 233,
#   'network_ability': 0.43521969441789377,
#   'promoted': 0},
#  {'competence': -0.28032015697509755,
#   'id': 234,
#   'network_ability': 1.5389601217827966,
#   'promoted': 1},
#  {'competence': -0.552576620826919,
#   'id': 235,
#   'network_ability': -0.18288663263221244,
#   'promoted': 0},
#  {'competence': 0.8933553735740456,
#   'id': 236,
#   'network_ability': 0.4317528418778745,
#   'promoted': 0},
#  {'competence': -0.6792046811803139,
#   'id': 237,
#   'network_ability': -0.0012387287042438752,
#   'promoted': 1},
#  {'competence': 0.004448926750241683,
#   'id': 238,
#   'network_ability': 0.983096560357001,
#   'promoted': 0},
#  {'competence': -0.6853166168507376,
#   'id': 239,
#   'network_ability': -1.572277781997637,
#   'promoted': 0},
#  {'competence': 0.1647280299421323,
#   'id': 240,
#   'network_ability': 0.9170862931084145,
#   'promoted': 0},
#  {'competence': -0.6450943673812058,
#   'id': 241,
#   'network_ability': -0.6957414288288262,
#   'promoted': 0},
#  {'competence': 0.4056929966405602,
#   'id': 242,
#   'network_ability': -0.5121562222663195,
#   'promoted': 0},
#  {'competence': 1.0547476857897515,
#   'id': 243,
#   'network_ability': 0.09765425454133933,
#   'promoted': 1},
#  {'competence': 0.521395452297732,
#   'id': 244,
#   'network_ability': 0.9499818565679767,
#   'promoted': 0},
#  {'competence': 2.201848111426214,
#   'id': 245,
#   'network_ability': -1.3586240668829432,
#   'promoted': 1},
#  {'competence': 0.82787416745655,
#   'id': 246,
#   'network_ability': 1.3259158603952235,
#   'promoted': 1},
#  {'competence': -2.3364911463948412,
#   'id': 247,
#   'network_ability': -1.4564404307449144,
#   'promoted': 0},
#  {'competence': -1.5941998071002648,
#   'id': 248,
#   'network_ability': 1.768823521386283,
#   'promoted': 1},
#  {'competence': 1.5212042266685928,
#   'id': 249,
#   'network_ability': -0.8417028094961722,
#   'promoted': 1},
#  {'competence': 1.1836492733982862,
#   'id': 250,
#   'network_ability': -0.2968944580139178,
#   'promoted': 1},
#  {'competence': -0.03538687925053646,
#   'id': 251,
#   'network_ability': 1.9678977629686782,
#   'promoted': 1},
#  {'competence': 0.825525589781541,
#   'id': 252,
#   'network_ability': 0.8768735992704264,
#   'promoted': 0},
#  {'competence': 1.5543962776070954,
#   'id': 253,
#   'network_ability': 0.9019329989044291,
#   'promoted': 1},
#  {'competence': -0.29801873198998996,
#   'id': 254,
#   'network_ability': -0.39413810183670434,
#   'promoted': 0},
#  {'competence': -1.9442146965034222,
#   'id': 255,
#   'network_ability': -0.5595369473698188,
#   'promoted': 0},
#  {'competence': -0.015245557230772254,
#   'id': 256,
#   'network_ability': -0.5960994409455869,
#   'promoted': 0},
#  {'competence': 0.011794027547566834,
#   'id': 257,
#   'network_ability': 0.13514808331632341,
#   'promoted': 0},
#  {'competence': 0.4207736141533239,
#   'id': 258,
#   'network_ability': 0.5314788415003726,
#   'promoted': 0},
#  {'competence': 0.22425786402382492,
#   'id': 259,
#   'network_ability': 0.6663443286946865,
#   'promoted': 0},
#  {'competence': -1.8373423976948515,
#   'id': 260,
#   'network_ability': -0.25979210591403357,
#   'promoted': 0},
#  {'competence': -0.8650853731645869,
#   'id': 261,
#   'network_ability': -0.6213127188088878,
#   'promoted': 0},
#  {'competence': 2.312342262799972,
#   'id': 262,
#   'network_ability': 0.5476911068781876,
#   'promoted': 1},
#  {'competence': -0.8922713317497424,
#   'id': 263,
#   'network_ability': 0.008231431754458847,
#   'promoted': 0},
#  {'competence': -0.8671618252092217,
#   'id': 264,
#   'network_ability': -0.2359057102783989,
#   'promoted': 0},
#  {'competence': -0.7173934777074515,
#   'id': 265,
#   'network_ability': 0.8365003782811606,
#   'promoted': 0},
#  {'competence': -0.6555437762897852,
#   'id': 266,
#   'network_ability': 0.3958557023127496,
#   'promoted': 0},
#  {'competence': 1.7016655979663176,
#   'id': 267,
#   'network_ability': 0.6888991763316131,
#   'promoted': 1},
#  {'competence': -0.6655709146612746,
#   'id': 268,
#   'network_ability': 0.32595637753467127,
#   'promoted': 0},
#  {'competence': -0.21087900182843053,
#   'id': 269,
#   'network_ability': 0.16989597142244783,
#   'promoted': 0},
#  {'competence': -0.1445105663844415,
#   'id': 270,
#   'network_ability': -0.9202030389440781,
#   'promoted': 0},
#  {'competence': 0.18002854021668094,
#   'id': 271,
#   'network_ability': -0.5668496722966198,
#   'promoted': 0},
#  {'competence': 0.5559563582289481,
#   'id': 272,
#   'network_ability': 2.520690823910372,
#   'promoted': 1},
#  {'competence': -0.2859821954065801,
#   'id': 273,
#   'network_ability': -0.41813518090097945,
#   'promoted': 0},
#  {'competence': -0.7034945805008335,
#   'id': 274,
#   'network_ability': -0.4211610261121754,
#   'promoted': 0},
#  {'competence': 1.4773217445936142,
#   'id': 275,
#   'network_ability': -0.2872278430019313,
#   'promoted': 1},
#  {'competence': -0.7461804340435557,
#   'id': 276,
#   'network_ability': -0.4451387305798197,
#   'promoted': 0},
#  {'competence': 0.015341904903617932,
#   'id': 277,
#   'network_ability': 0.6558126431731313,
#   'promoted': 0},
#  {'competence': 0.9107191768152052,
#   'id': 278,
#   'network_ability': -0.49985340115144977,
#   'promoted': 0},
#  {'competence': -0.39802610395269433,
#   'id': 279,
#   'network_ability': 0.05967434496620416,
#   'promoted': 0},
#  {'competence': -2.113418678531315,
#   'id': 280,
#   'network_ability': -1.7880841376739127,
#   'promoted': 0},
#  {'competence': -1.0167925170473608,
#   'id': 281,
#   'network_ability': 0.6144467301018448,
#   'promoted': 0},
#  {'competence': -0.31816453025778735,
#   'id': 282,
#   'network_ability': 0.9979230353040386,
#   'promoted': 0},
#  {'competence': -1.3179667026495956,
#   'id': 283,
#   'network_ability': -0.06673764342744953,
#   'promoted': 0},
#  {'competence': -1.1726632485129473,
#   'id': 284,
#   'network_ability': 1.1309959948401462,
#   'promoted': 1},
#  {'competence': 0.05290123411192622,
#   'id': 285,
#   'network_ability': 0.4706468569850067,
#   'promoted': 0},
#  {'competence': 0.8156249286644408,
#   'id': 286,
#   'network_ability': 1.059722169635258,
#   'promoted': 1},
#  {'competence': 0.06161348694350342,
#   'id': 287,
#   'network_ability': -0.9661480129218308,
#   'promoted': 0},
#  {'competence': -1.8123771882591604,
#   'id': 288,
#   'network_ability': 0.20247278402710692,
#   'promoted': 0},
#  {'competence': 0.4075769458356285,
#   'id': 289,
#   'network_ability': -1.4202974733576224,
#   'promoted': 0},
#  {'competence': 1.3857242351804953,
#   'id': 290,
#   'network_ability': 0.6272489574693428,
#   'promoted': 1},
#  {'competence': 0.022954401999935276,
#   'id': 291,
#   'network_ability': 0.4580979504931936,
#   'promoted': 0},
#  {'competence': -0.8383560584029688,
#   'id': 292,
#   'network_ability': 0.1996528242628446,
#   'promoted': 0},
#  {'competence': -1.985714948738284,
#   'id': 293,
#   'network_ability': -0.7449522035539458,
#   'promoted': 1},
#  {'competence': 0.2746686394008686,
#   'id': 294,
#   'network_ability': 1.6406733502991053,
#   'promoted': 1},
#  {'competence': -0.2272592748037197,
#   'id': 295,
#   'network_ability': -1.079521713265325,
#   'promoted': 0},
#  {'competence': -0.0808147672994338,
#   'id': 296,
#   'network_ability': 0.6579309868778118,
#   'promoted': 0},
#  {'competence': -0.9605684842623814,
#   'id': 297,
#   'network_ability': 0.5091187776385936,
#   'promoted': 0},
#  {'competence': 0.896685397423851,
#   'id': 298,
#   'network_ability': 0.5373257756679686,
#   'promoted': 0},
#  {'competence': -0.7181626121947233,
#   'id': 299,
#   'network_ability': 0.10507708619439914,
#   'promoted': 0},
#  {'competence': 0.6509880859624185,
#   'id': 300,
#   'network_ability': 0.045763077927762255,
#   'promoted': 0},
#  {'competence': 2.354269679755495,
#   'id': 301,
#   'network_ability': 0.3663305045719205,
#   'promoted': 1},
#  {'competence': 0.2170710971376339,
#   'id': 302,
#   'network_ability': -0.8840275810321352,
#   'promoted': 0},
#  {'competence': 1.3005060220785203,
#   'id': 303,
#   'network_ability': -0.42550217671263785,
#   'promoted': 1},
#  {'competence': 0.16863665936599395,
#   'id': 304,
#   'network_ability': 1.4801403001428777,
#   'promoted': 0},
#  {'competence': -0.832774818270453,
#   'id': 305,
#   'network_ability': -0.581336134078761,
#   'promoted': 0},
#  {'competence': -0.37970700874970326,
#   'id': 306,
#   'network_ability': -0.025542665314869137,
#   'promoted': 0},
#  {'competence': -1.8199273267963232,
#   'id': 307,
#   'network_ability': -3.044296333379217,
#   'promoted': 0},
#  {'competence': 1.9087301775107288,
#   'id': 308,
#   'network_ability': -0.5147766801155148,
#   'promoted': 1},
#  {'competence': 0.7400404605588073,
#   'id': 309,
#   'network_ability': -0.6953304827719191,
#   'promoted': 1},
#  {'competence': -1.5839008797862397,
#   'id': 310,
#   'network_ability': 0.384357785868137,
#   'promoted': 0},
#  {'competence': 1.2833591415662837,
#   'id': 311,
#   'network_ability': 0.6717208216140621,
#   'promoted': 1},
#  {'competence': 0.33836189967932095,
#   'id': 312,
#   'network_ability': -1.5611649503954486,
#   'promoted': 1},
#  {'competence': -2.1099973400459766,
#   'id': 313,
#   'network_ability': -0.2949063439806421,
#   'promoted': 1},
#  {'competence': -0.5887644878396596,
#   'id': 314,
#   'network_ability': 1.9443449273353333,
#   'promoted': 1},
#  {'competence': -1.1784589477258764,
#   'id': 315,
#   'network_ability': 0.5491554027073748,
#   'promoted': 0},
#  {'competence': 1.7177941392102647,
#   'id': 316,
#   'network_ability': -0.9187586028991009,
#   'promoted': 1},
#  {'competence': 1.32746391622772,
#   'id': 317,
#   'network_ability': -0.42163357123285305,
#   'promoted': 1},
#  {'competence': 0.4255946804613917,
#   'id': 318,
#   'network_ability': -1.5809864122377455,
#   'promoted': 0},
#  {'competence': -0.4281749365227617,
#   'id': 319,
#   'network_ability': -0.22050375245514514,
#   'promoted': 0},
#  {'competence': 0.5623969355913979,
#   'id': 320,
#   'network_ability': 1.4229206368994822,
#   'promoted': 1},
#  {'competence': 0.3059758917804065,
#   'id': 321,
#   'network_ability': 0.6356083020195225,
#   'promoted': 0},
#  {'competence': -0.511772835042438,
#   'id': 322,
#   'network_ability': 0.5166223117363787,
#   'promoted': 0},
#  {'competence': 0.9205356684394906,
#   'id': 323,
#   'network_ability': 0.5950378357029771,
#   'promoted': 0},
#  {'competence': 0.6540460645613217,
#   'id': 324,
#   'network_ability': -0.6904682335599249,
#   'promoted': 0},
#  {'competence': 0.11288403083522416,
#   'id': 325,
#   'network_ability': 0.2759164319304305,
#   'promoted': 0},
#  {'competence': -0.8182084123017066,
#   'id': 326,
#   'network_ability': -0.999511966143434,
#   'promoted': 0},
#  {'competence': 1.5536035490584772,
#   'id': 327,
#   'network_ability': 1.3520982817774807,
#   'promoted': 1},
#  {'competence': -0.046671773236791426,
#   'id': 328,
#   'network_ability': 0.22585788955802033,
#   'promoted': 0},
#  {'competence': -0.8943669585718043,
#   'id': 329,
#   'network_ability': 0.7437755611592332,
#   'promoted': 0},
#  {'competence': -0.4800995019803846,
#   'id': 330,
#   'network_ability': -0.5549250420797737,
#   'promoted': 0},
#  {'competence': 1.06532249173273,
#   'id': 331,
#   'network_ability': 0.8521080285666899,
#   'promoted': 1},
#  {'competence': 0.0507894926665905,
#   'id': 332,
#   'network_ability': -0.6070296740396895,
#   'promoted': 0},
#  {'competence': -0.35275196481491894,
#   'id': 333,
#   'network_ability': 0.2860957976173605,
#   'promoted': 0},
#  {'competence': -0.0032454392974157085,
#   'id': 334,
#   'network_ability': -1.1172496623634744,
#   'promoted': 0},
#  {'competence': -0.2707792647223684,
#   'id': 335,
#   'network_ability': 0.8583714225341567,
#   'promoted': 0},
#  {'competence': -1.5425806418098669,
#   'id': 336,
#   'network_ability': -2.9646815539564284,
#   'promoted': 0},
#  {'competence': 0.5190391815176223,
#   'id': 337,
#   'network_ability': 0.6143448024114223,
#   'promoted': 0},
#  {'competence': 0.6609070396778741,
#   'id': 338,
#   'network_ability': 2.2923480917295698,
#   'promoted': 1},
#  {'competence': 0.6890123308955264,
#   'id': 339,
#   'network_ability': -0.6795227455004398,
#   'promoted': 0},
#  {'competence': -0.5086221594401674,
#   'id': 340,
#   'network_ability': -1.787731482547943,
#   'promoted': 0},
#  {'competence': 0.31698173110413774,
#   'id': 341,
#   'network_ability': 0.9690794633527126,
#   'promoted': 0},
#  {'competence': 1.362627874048639,
#   'id': 342,
#   'network_ability': -1.1885039532834856,
#   'promoted': 1},
#  {'competence': 0.41315908449176414,
#   'id': 343,
#   'network_ability': 0.10411926537879324,
#   'promoted': 0},
#  {'competence': -1.1889613601746565,
#   'id': 344,
#   'network_ability': -1.0960508528128718,
#   'promoted': 0},
#  {'competence': -0.6077602806203088,
#   'id': 345,
#   'network_ability': 0.5403153325268601,
#   'promoted': 0},
#  {'competence': 1.4397304373189765,
#   'id': 346,
#   'network_ability': 0.019987200175703164,
#   'promoted': 1},
#  {'competence': 0.911535520896091,
#   'id': 347,
#   'network_ability': -0.413952268729825,
#   'promoted': 0},
#  {'competence': -0.6989084232012526,
#   'id': 348,
#   'network_ability': -1.141869323680158,
#   'promoted': 0},
#  {'competence': 1.2056273925356342,
#   'id': 349,
#   'network_ability': -0.5254709262038186,
#   'promoted': 1},
#  {'competence': 0.3550526244067665,
#   'id': 350,
#   'network_ability': -0.795239756599353,
#   'promoted': 0},
#  {'competence': 0.6629031950348985,
#   'id': 351,
#   'network_ability': -0.6580962561886682,
#   'promoted': 0},
#  {'competence': -0.07116198678814876,
#   'id': 352,
#   'network_ability': -0.2700062858898621,
#   'promoted': 0},
#  {'competence': -1.166082829231359,
#   'id': 353,
#   'network_ability': -1.4781266775638364,
#   'promoted': 0},
#  {'competence': 0.13543663355936467,
#   'id': 354,
#   'network_ability': -2.045799150818049,
#   'promoted': 0},
#  {'competence': 0.6811121527430822,
#   'id': 355,
#   'network_ability': -1.9696870833461908,
#   'promoted': 0},
#  {'competence': -1.6325744604211327,
#   'id': 356,
#   'network_ability': 0.4997966024666687,
#   'promoted': 0},
#  {'competence': 1.8598944870846397,
#   'id': 357,
#   'network_ability': -0.9149336248816049,
#   'promoted': 1},
#  {'competence': 0.8794738314192515,
#   'id': 358,
#   'network_ability': -0.9924426911873865,
#   'promoted': 0},
#  {'competence': 0.1416610564165516,
#   'id': 359,
#   'network_ability': -0.3228658453530463,
#   'promoted': 0},
#  {'competence': -0.9011026802757104,
#   'id': 360,
#   'network_ability': -0.8615179861318918,
#   'promoted': 0},
#  {'competence': -0.12252517804525227,
#   'id': 361,
#   'network_ability': -0.9090365381286954,
#   'promoted': 0},
#  {'competence': -1.4738902925137578,
#   'id': 362,
#   'network_ability': 0.10530887439669688,
#   'promoted': 0},
#  {'competence': 0.1620060972417758,
#   'id': 363,
#   'network_ability': -1.0620356733177128,
#   'promoted': 0},
#  {'competence': 2.483546890501886,
#   'id': 364,
#   'network_ability': 0.4870147888569117,
#   'promoted': 1},
#  {'competence': 0.44783892693015426,
#   'id': 365,
#   'network_ability': -0.4215627313256701,
#   'promoted': 0},
#  {'competence': -0.422073069431792,
#   'id': 366,
#   'network_ability': -2.077316479876013,
#   'promoted': 0},
#  {'competence': 1.625958729844465,
#   'id': 367,
#   'network_ability': -0.4948113731855317,
#   'promoted': 1},
#  {'competence': -0.8481334762605511,
#   'id': 368,
#   'network_ability': -0.6345540953888039,
#   'promoted': 0},
#  {'competence': -0.14593442726202688,
#   'id': 369,
#   'network_ability': -1.5597109545957735,
#   'promoted': 0},
#  {'competence': -0.2892360042848637,
#   'id': 370,
#   'network_ability': -0.23174167348194366,
#   'promoted': 0},
#  {'competence': 0.38619559865169384,
#   'id': 371,
#   'network_ability': 0.014008678037687726,
#   'promoted': 0},
#  {'competence': -0.21870666963716903,
#   'id': 372,
#   'network_ability': 1.60140842090723,
#   'promoted': 1},
#  {'competence': 0.3144974631027601,
#   'id': 373,
#   'network_ability': -0.3006920742321125,
#   'promoted': 0},
#  {'competence': -1.3536740432533543,
#   'id': 374,
#   'network_ability': 0.6190094620767749,
#   'promoted': 0},
#  {'competence': 0.36776774163990356,
#   'id': 375,
#   'network_ability': 1.626900007361335,
#   'promoted': 0},
#  {'competence': 0.11158234626017413,
#   'id': 376,
#   'network_ability': 0.42890495267937284,
#   'promoted': 0},
#  {'competence': 0.46951917795759485,
#   'id': 377,
#   'network_ability': 1.6574767398868342,
#   'promoted': 1},
#  {'competence': -0.9449828847572385,
#   'id': 378,
#   'network_ability': -1.2432838327045448,
#   'promoted': 0},
#  {'competence': 2.454587140484884,
#   'id': 379,
#   'network_ability': -1.4952788654098965,
#   'promoted': 1},
#  {'competence': 1.2424648794270552,
#   'id': 380,
#   'network_ability': 0.3417845156067338,
#   'promoted': 1},
#  {'competence': 0.17184456097305564,
#   'id': 381,
#   'network_ability': 0.4866657824330327,
#   'promoted': 0},
#  {'competence': -0.43644992165105884,
#   'id': 382,
#   'network_ability': -2.3230250143690148,
#   'promoted': 0},
#  {'competence': -0.8883273179626857,
#   'id': 383,
#   'network_ability': -0.8189270737907274,
#   'promoted': 0},
#  {'competence': 0.2905935023872751,
#   'id': 384,
#   'network_ability': -0.04636062634709769,
#   'promoted': 0},
#  {'competence': -0.5745525054982146,
#   'id': 385,
#   'network_ability': -1.2765578188685884,
#   'promoted': 0},
#  {'competence': -0.6490246587809247,
#   'id': 386,
#   'network_ability': -0.323114408072617,
#   'promoted': 0},
#  {'competence': -0.2748124939362693,
#   'id': 387,
#   'network_ability': 0.5177778217295489,
#   'promoted': 0},
#  {'competence': 0.04223445111515807,
#   'id': 388,
#   'network_ability': -0.08621963346293283,
#   'promoted': 1},
#  {'competence': 0.5691676392285953,
#   'id': 389,
#   'network_ability': 0.5860042796308432,
#   'promoted': 0},
#  {'competence': 1.1120621217264786,
#   'id': 390,
#   'network_ability': 1.4727505678335673,
#   'promoted': 1},
#  {'competence': -1.490125261247663,
#   'id': 391,
#   'network_ability': 1.7617162531066228,
#   'promoted': 1},
#  {'competence': 0.4811449863416219,
#   'id': 392,
#   'network_ability': -1.1465117416757558,
#   'promoted': 0},
#  {'competence': -1.4573074231895904,
#   'id': 393,
#   'network_ability': 0.19399842106252413,
#   'promoted': 0},
#  {'competence': 0.9443138837778547,
#   'id': 394,
#   'network_ability': -0.5291918915956438,
#   'promoted': 0},
#  {'competence': -1.8711840190113114,
#   'id': 395,
#   'network_ability': -0.4770581325818086,
#   'promoted': 0},
#  {'competence': -2.0382473802331487,
#   'id': 396,
#   'network_ability': -1.8983431533094255,
#   'promoted': 0},
#  {'competence': -1.1051725578976446,
#   'id': 397,
#   'network_ability': -1.097315852820673,
#   'promoted': 0},
#  {'competence': 0.005978659450120758,
#   'id': 398,
#   'network_ability': 0.6046140598018492,
#   'promoted': 1},
#  {'competence': 0.5131992420654619,
#   'id': 399,
#   'network_ability': 1.0065821219267697,
#   'promoted': 1},
#  {'competence': -0.08420652825220952,
#   'id': 400,
#   'network_ability': 0.03177375030170918,
#   'promoted': 0},
#  {'competence': -0.036188074920689706,
#   'id': 401,
#   'network_ability': -0.9358994310059997,
#   'promoted': 0},
#  {'competence': -1.6083042639735312,
#   'id': 402,
#   'network_ability': 0.18209599324899137,
#   'promoted': 0},
#  {'competence': 0.4468267536268102,
#   'id': 403,
#   'network_ability': 1.3163967210581107,
#   'promoted': 1},
#  {'competence': 0.7306240556198402,
#   'id': 404,
#   'network_ability': -0.8130225336047574,
#   'promoted': 0},
#  {'competence': 1.3435991716737006,
#   'id': 405,
#   'network_ability': -0.9377878783951478,
#   'promoted': 1},
#  {'competence': 1.6366553796599348,
#   'id': 406,
#   'network_ability': 0.92558372061226,
#   'promoted': 0},
#  {'competence': -0.0438206684050528,
#   'id': 407,
#   'network_ability': -0.40659541683158623,
#   'promoted': 0},
#  {'competence': 1.5576871499524851,
#   'id': 408,
#   'network_ability': 0.7320918740714205,
#   'promoted': 1},
#  {'competence': 1.2199065167359158,
#   'id': 409,
#   'network_ability': -0.08204206366934373,
#   'promoted': 1},
#  {'competence': -1.634944896741972,
#   'id': 410,
#   'network_ability': -0.5438740687390079,
#   'promoted': 0},
#  {'competence': -1.3656640790433667,
#   'id': 411,
#   'network_ability': 0.6602971621692246,
#   'promoted': 0},
#  {'competence': 1.3029667254600577,
#   'id': 412,
#   'network_ability': 0.045278150305891475,
#   'promoted': 1},
#  {'competence': -0.06219973267441679,
#   'id': 413,
#   'network_ability': 2.0596728341152533,
#   'promoted': 1},
#  {'competence': 0.49453032760082705,
#   'id': 414,
#   'network_ability': 0.3393050703235377,
#   'promoted': 0},
#  {'competence': 0.49750164335013514,
#   'id': 415,
#   'network_ability': -1.3760605798834007,
#   'promoted': 0},
#  {'competence': -1.4868957732461705,
#   'id': 416,
#   'network_ability': 0.21639954895809033,
#   'promoted': 0},
#  {'competence': 0.2728972529829651,
#   'id': 417,
#   'network_ability': -0.8930520131002863,
#   'promoted': 0},
#  {'competence': 1.4681643221458742,
#   'id': 418,
#   'network_ability': -0.8096624187615417,
#   'promoted': 1},
#  {'competence': 0.41453165963657634,
#   'id': 419,
#   'network_ability': 0.2115097879359538,
#   'promoted': 0},
#  {'competence': 1.9591750348583492,
#   'id': 420,
#   'network_ability': 0.12992438694397718,
#   'promoted': 1},
#  {'competence': 1.0863155782246572,
#   'id': 421,
#   'network_ability': -2.1618305526390107,
#   'promoted': 1},
#  {'competence': 0.8010326356287376,
#   'id': 422,
#   'network_ability': -0.3572816768038426,
#   'promoted': 0},
#  {'competence': -1.4353404190191206,
#   'id': 423,
#   'network_ability': 0.8405480545183033,
#   'promoted': 0},
#  {'competence': -0.7994196463176565,
#   'id': 424,
#   'network_ability': 0.5331290978288225,
#   'promoted': 0},
#  {'competence': -0.02559908502986735,
#   'id': 425,
#   'network_ability': 1.556670355534395,
#   'promoted': 1},
#  {'competence': 1.4914662718847684,
#   'id': 426,
#   'network_ability': -0.5174302628451752,
#   'promoted': 1},
#  {'competence': -0.8858226678221921,
#   'id': 427,
#   'network_ability': -0.5688528326971086,
#   'promoted': 0},
#  {'competence': 0.6229838073892929,
#   'id': 428,
#   'network_ability': -2.2758352708664225,
#   'promoted': 0},
#  {'competence': 0.602010610081595,
#   'id': 429,
#   'network_ability': 0.6226856250382069,
#   'promoted': 1},
#  {'competence': 0.7935052368236414,
#   'id': 430,
#   'network_ability': -0.136114242002121,
#   'promoted': 0},
#  {'competence': 0.585172484470375,
#   'id': 431,
#   'network_ability': -0.042985332205496246,
#   'promoted': 0},
#  {'competence': 1.0751008710389,
#   'id': 432,
#   'network_ability': 0.4950628531430368,
#   'promoted': 1},
#  {'competence': 2.32907925555966,
#   'id': 433,
#   'network_ability': 0.011838466630361857,
#   'promoted': 1},
#  {'competence': -0.2422232577312851,
#   'id': 434,
#   'network_ability': -0.19238549188767187,
#   'promoted': 0},
#  {'competence': -0.4869665251107876,
#   'id': 435,
#   'network_ability': 1.2688240643938022,
#   'promoted': 1},
#  {'competence': 0.4226023818043857,
#   'id': 436,
#   'network_ability': 0.6632447110124532,
#   'promoted': 0},
#  {'competence': 1.201776697675616,
#   'id': 437,
#   'network_ability': 0.2186200350216321,
#   'promoted': 1},
#  {'competence': -0.5507512191477175,
#   'id': 438,
#   'network_ability': -0.2550581597851623,
#   'promoted': 0},
#  {'competence': 2.171028721048591,
#   'id': 439,
#   'network_ability': 0.6508495370169917,
#   'promoted': 1},
#  {'competence': 1.6836267705170662,
#   'id': 440,
# ...
#   'network_ability': -0.7036372817972716,
#   'promoted': 0},
#  {'competence': -0.9157838163912987,
#   'id': 854,
#   'network_ability': 0.5083713647147835,
#   'promoted': 1},
#  {'competence': -0.5542656977799948,
#   'id': 855,
#   'network_ability': -2.123570902594836,
#   'promoted': 0},
#  {'competence': -0.33169561644262224,
#   'id': 856,
#   'network_ability': 0.16345748633161694,
#   'promoted': 0},
#  {'competence': -0.6617408501171018,
#   'id': 857,
#   'network_ability': -0.17591155678413153,
#   'promoted': 0},
#  {'competence': 0.966237394650221,
#   'id': 858,
#   'network_ability': -0.8399360104283671,
#   'promoted': 0},
#  {'competence': 0.8226466927735179,
#   'id': 859,
#   'network_ability': 0.24102730988322743,
#   'promoted': 0},
#  {'competence': 0.16615125862030855,
#   'id': 860,
#   'network_ability': -1.4295635815767709,
#   'promoted': 0},
#  {'competence': 0.951361169775217,
#   'id': 861,
#   'network_ability': 0.9820134487396672,
#   'promoted': 0},
#  {'competence': 0.3693366498647928,
#   'id': 862,
#   'network_ability': -0.7131437206665588,
#   'promoted': 0},
#  {'competence': 1.068155049219481,
#   'id': 863,
#   'network_ability': -1.0596014497771977,
#   'promoted': 1},
#  {'competence': -0.01782084791995111,
#   'id': 864,
#   'network_ability': 0.5325737640175986,
#   'promoted': 0},
#  {'competence': -0.37631422473897147,
#   'id': 865,
#   'network_ability': 0.1320266371267539,
#   'promoted': 0},
#  {'competence': 1.6882245245551613,
#   'id': 866,
#   'network_ability': -0.7579406310327443,
#   'promoted': 1},
#  {'competence': 1.8036930217352285,
#   'id': 867,
#   'network_ability': 1.371581065294111,
#   'promoted': 1},
#  {'competence': -0.9476541338560837,
#   'id': 868,
#   'network_ability': -0.4152740560887429,
#   'promoted': 0},
#  {'competence': -1.133930180706591,
#   'id': 869,
#   'network_ability': 0.9561313233998441,
#   'promoted': 0},
#  {'competence': -0.444490729164126,
#   'id': 870,
#   'network_ability': 0.4040196088170158,
#   'promoted': 0},
#  {'competence': -0.6800488040811558,
#   'id': 871,
#   'network_ability': 0.5322847636133539,
#   'promoted': 0},
#  {'competence': 2.092144251635853,
#   'id': 872,
#   'network_ability': 1.2496683069303078,
#   'promoted': 1},
#  {'competence': 1.787349386577624,
#   'id': 873,
#   'network_ability': -0.8857813293670738,
#   'promoted': 1},
#  {'competence': 0.0048870457889686,
#   'id': 874,
#   'network_ability': 0.3089551730067843,
#   'promoted': 0},
#  {'competence': 1.4346016205117194,
#   'id': 875,
#   'network_ability': 1.1209246678024618,
#   'promoted': 1},
#  {'competence': 0.3659063670820608,
#   'id': 876,
#   'network_ability': 0.055604982496313536,
#   'promoted': 0},
#  {'competence': -1.7771107915550326,
#   'id': 877,
#   'network_ability': 0.7472626308473703,
#   'promoted': 0},
#  {'competence': -0.45727288970744057,
#   'id': 878,
#   'network_ability': -1.068202784141997,
#   'promoted': 0},
#  {'competence': -0.19091051682879287,
#   'id': 879,
#   'network_ability': -0.27224426808427704,
#   'promoted': 0},
#  {'competence': -0.4699029679242685,
#   'id': 880,
#   'network_ability': -1.0386447186901888,
#   'promoted': 0},
#  {'competence': 0.3670353563152368,
#   'id': 881,
#   'network_ability': 0.3101200824706833,
#   'promoted': 0},
#  {'competence': 0.676211420052603,
#   'id': 882,
#   'network_ability': -0.3325810408833827,
#   'promoted': 0},
#  {'competence': 0.525963544648696,
#   'id': 883,
#   'network_ability': -1.9883107496792611,
#   'promoted': 0},
#  {'competence': -1.1529335481996354,
#   'id': 884,
#   'network_ability': -0.48370518253095324,
#   'promoted': 0},
#  {'competence': -1.5151766463900564,
#   'id': 885,
#   'network_ability': -0.3583333591282556,
#   'promoted': 0},
#  {'competence': 0.09183061590883455,
#   'id': 886,
#   'network_ability': -0.3491357653933543,
#   'promoted': 0},
#  {'competence': -0.13564874353714548,
#   'id': 887,
#   'network_ability': -0.46344417954476264,
#   'promoted': 0},
#  {'competence': 0.3835243723658755,
#   'id': 888,
#   'network_ability': -0.7465980448485462,
#   'promoted': 0},
#  {'competence': -0.6975620182259618,
#   'id': 889,
#   'network_ability': 0.49716866695197526,
#   'promoted': 0},
#  {'competence': -0.8891769836834901,
#   'id': 890,
#   'network_ability': -0.4473392112522368,
#   'promoted': 0},
#  {'competence': -0.1724170790889193,
#   'id': 891,
#   'network_ability': 0.19926626289900123,
#   'promoted': 0},
#  {'competence': -0.5265243009034227,
#   'id': 892,
#   'network_ability': -0.132733606559292,
#   'promoted': 0},
#  {'competence': -0.697512897248208,
#   'id': 893,
#   'network_ability': 0.4960039669790972,
#   'promoted': 0},
#  {'competence': 0.4548559007938749,
#   'id': 894,
#   'network_ability': 1.0175805958148758,
#   'promoted': 1},
#  {'competence': 0.33944359091483406,
#   'id': 895,
#   'network_ability': 0.2046760866917252,
#   'promoted': 1},
#  {'competence': 0.26513972911291744,
#   'id': 896,
#   'network_ability': -0.3724929210968681,
#   'promoted': 0},
#  {'competence': -0.8781527492773815,
#   'id': 897,
#   'network_ability': 0.03527335270373955,
#   'promoted': 0},
#  {'competence': 0.007842212858144916,
#   'id': 898,
#   'network_ability': -1.7081694118548907,
#   'promoted': 0},
#  {'competence': -0.03855390854689766,
#   'id': 899,
#   'network_ability': 0.10979042466518114,
#   'promoted': 0},
#  {'competence': 0.3437599722366144,
#   'id': 900,
#   'network_ability': 1.8407442788455324,
#   'promoted': 1},
#  {'competence': 0.39223133289881823,
#   'id': 901,
#   'network_ability': -0.12365068347270372,
#   'promoted': 0},
#  {'competence': 0.6288403995776657,
#   'id': 902,
#   'network_ability': -2.1023378538787165,
#   'promoted': 0},
#  {'competence': 0.08030164961926868,
#   'id': 903,
#   'network_ability': 0.4762707595364674,
#   'promoted': 0},
#  {'competence': 0.043856468816234666,
#   'id': 904,
#   'network_ability': -2.207556187210259,
#   'promoted': 0},
#  {'competence': 0.6434269384963062,
#   'id': 905,
#   'network_ability': -0.04136836200475942,
#   'promoted': 0},
#  {'competence': -1.4590054991643702,
#   'id': 906,
#   'network_ability': -1.997430168502327,
#   'promoted': 0},
#  {'competence': 0.05873579874693329,
#   'id': 907,
#   'network_ability': 0.6188209658946675,
#   'promoted': 0},
#  {'competence': -2.2990839840870647,
#   'id': 908,
#   'network_ability': -0.007236912763513837,
#   'promoted': 0},
#  {'competence': -0.8500545413531729,
#   'id': 909,
#   'network_ability': -0.025921500233352747,
#   'promoted': 0},
#  {'competence': -0.581688586640885,
#   'id': 910,
#   'network_ability': 0.5323078887361499,
#   'promoted': 0},
#  {'competence': -1.4775899306096902,
#   'id': 911,
#   'network_ability': -1.1599623472938052,
#   'promoted': 0},
#  {'competence': -0.49825436944146795,
#   'id': 912,
#   'network_ability': -1.0889843099993621,
#   'promoted': 0},
#  {'competence': 1.378377011117931,
#   'id': 913,
#   'network_ability': 0.2027668931887576,
#   'promoted': 1},
#  {'competence': -1.752634648608009,
#   'id': 914,
#   'network_ability': 0.6243021267721126,
#   'promoted': 0},
#  {'competence': 1.4495192695322068,
#   'id': 915,
#   'network_ability': -0.9604722370135037,
#   'promoted': 1},
#  {'competence': 0.5521754390673228,
#   'id': 916,
#   'network_ability': 2.52817706859418,
#   'promoted': 1},
#  {'competence': -0.6472310047013433,
#   'id': 917,
#   'network_ability': 1.6928510212877188,
#   'promoted': 1},
#  {'competence': -0.6334791355553789,
#   'id': 918,
#   'network_ability': 1.1687412236791377,
#   'promoted': 1},
#  {'competence': 1.604437874966436,
#   'id': 919,
#   'network_ability': -0.24028563130949254,
#   'promoted': 1},
#  {'competence': 0.5463964655199922,
#   'id': 920,
#   'network_ability': -1.7310194802704821,
#   'promoted': 0},
#  {'competence': 0.12729861451210972,
#   'id': 921,
#   'network_ability': -2.026822894545615,
#   'promoted': 1},
#  {'competence': 0.4989619124701693,
#   'id': 922,
#   'network_ability': -0.7088934473076057,
#   'promoted': 0},
#  {'competence': 0.3528294970618884,
#   'id': 923,
#   'network_ability': -0.8861501256772131,
#   'promoted': 0},
#  {'competence': 0.3736848471285553,
#   'id': 924,
#   'network_ability': -0.047070284928647975,
#   'promoted': 0},
#  {'competence': -2.640078348251302,
#   'id': 925,
#   'network_ability': 1.7103901886748534,
#   'promoted': 1},
#  {'competence': -0.5879366554244438,
#   'id': 926,
#   'network_ability': 1.1541128686655677,
#   'promoted': 1},
#  {'competence': -0.5668332741532629,
#   'id': 927,
#   'network_ability': -0.7281506157982809,
#   'promoted': 0},
#  {'competence': 1.3031876363834702,
#   'id': 928,
#   'network_ability': -0.9206790387879247,
#   'promoted': 1},
#  {'competence': 0.18173376701052837,
#   'id': 929,
#   'network_ability': 2.169821428721613,
#   'promoted': 1},
#  {'competence': 0.3089991712007606,
#   'id': 930,
#   'network_ability': 0.013837538077815755,
#   'promoted': 0},
#  {'competence': -0.01788225802365629,
#   'id': 931,
#   'network_ability': -0.2263434319702126,
#   'promoted': 0},
#  {'competence': 0.5064262812355108,
#   'id': 932,
#   'network_ability': 0.5483279035251601,
#   'promoted': 0},
#  {'competence': 0.9837920547149231,
#   'id': 933,
#   'network_ability': -1.5450762680860524,
#   'promoted': 0},
#  {'competence': -0.04590511247447397,
#   'id': 934,
#   'network_ability': 0.8464496435624312,
#   'promoted': 0},
#  {'competence': 0.5920744420925727,
#   'id': 935,
#   'network_ability': -2.2994360639586255,
#   'promoted': 0},
#  {'competence': -0.7092816139650361,
#   'id': 936,
#   'network_ability': -1.533899252141969,
#   'promoted': 0},
#  {'competence': -0.6788978752056803,
#   'id': 937,
#   'network_ability': 0.7458787895741565,
#   'promoted': 0},
#  {'competence': 1.228402847079261,
#   'id': 938,
#   'network_ability': 0.4491974164926044,
#   'promoted': 1},
#  {'competence': -0.38043694636956327,
#   'id': 939,
#   'network_ability': -2.7180913823559987,
#   'promoted': 0},
#  {'competence': 1.3040865551574012,
#   'id': 940,
#   'network_ability': 0.13328418465252465,
#   'promoted': 1},
#  {'competence': -0.9928593029148669,
#   'id': 941,
#   'network_ability': 1.2405302241290364,
#   'promoted': 0},
#  {'competence': 1.33867919748948,
#   'id': 942,
#   'network_ability': -0.12541678812773435,
#   'promoted': 1},
#  {'competence': 0.1847305614747796,
#   'id': 943,
#   'network_ability': -2.380183757963448,
#   'promoted': 0},
#  {'competence': 0.44262868996328886,
#   'id': 944,
#   'network_ability': -0.13444074020434782,
#   'promoted': 0},
#  {'competence': -0.3898655762702697,
#   'id': 945,
#   'network_ability': 0.2938206889629666,
#   'promoted': 0},
#  {'competence': 1.4430063487126663,
#   'id': 946,
#   'network_ability': -0.5324541647219002,
#   'promoted': 1},
#  {'competence': -0.8423264009896537,
#   'id': 947,
#   'network_ability': -0.2589180424040175,
#   'promoted': 0},
#  {'competence': 1.241429009089907,
#   'id': 948,
#   'network_ability': -1.3763274956867462,
#   'promoted': 1},
#  {'competence': -1.3654715093286238,
#   'id': 949,
#   'network_ability': 1.0387452563163326,
#   'promoted': 1},
#  {'competence': -0.20951834013407467,
#   'id': 950,
#   'network_ability': -0.6933344084268607,
#   'promoted': 0},
#  {'competence': 1.384732323580462,
#   'id': 951,
#   'network_ability': -2.1873538327940594,
#   'promoted': 1},
#  {'competence': -0.2340194595328164,
#   'id': 952,
#   'network_ability': 0.8180731305220075,
#   'promoted': 0},
#  {'competence': 2.3507550420725685,
#   'id': 953,
#   'network_ability': 1.6789331293321195,
#   'promoted': 1},
#  {'competence': -0.727623263944978,
#   'id': 954,
#   'network_ability': 0.08797601728263156,
#   'promoted': 0},
#  {'competence': -0.17371146620659644,
#   'id': 955,
#   'network_ability': -2.043771383942744,
#   'promoted': 0},
#  {'competence': 1.6057291819651685,
#   'id': 956,
#   'network_ability': 0.4157977399609288,
#   'promoted': 1},
#  {'competence': 0.36316482182749815,
#   'id': 957,
#   'network_ability': -0.50395830593011,
#   'promoted': 0},
#  {'competence': -1.0954563037271825,
#   'id': 958,
#   'network_ability': -0.6031610441365279,
#   'promoted': 0},
#  {'competence': -0.02838286614057841,
#   'id': 959,
#   'network_ability': -0.5065509814969189,
#   'promoted': 0},
#  {'competence': -0.9942121725426489,
#   'id': 960,
#   'network_ability': 1.1293610378178864,
#   'promoted': 1},
#  {'competence': 0.9911608939685843,
#   'id': 961,
#   'network_ability': 0.5915619366262549,
#   'promoted': 0},
#  {'competence': 2.243997216971262,
#   'id': 962,
#   'network_ability': 0.07438921649110988,
#   'promoted': 1},
#  {'competence': 0.5281042349260221,
#   'id': 963,
#   'network_ability': 0.13395781569816087,
#   'promoted': 1},
#  {'competence': -0.2532504831244075,
#   'id': 964,
#   'network_ability': 0.48039001922827396,
#   'promoted': 0},
#  {'competence': -0.9851559406080531,
#   'id': 965,
#   'network_ability': 0.7169934136978242,
#   'promoted': 0},
#  {'competence': -0.2647409718427649,
#   'id': 966,
#   'network_ability': -0.6818415019425549,
#   'promoted': 0},
#  {'competence': -1.587832447941403,
#   'id': 967,
#   'network_ability': -0.21094343227276205,
#   'promoted': 0},
#  {'competence': -1.5114389178402938,
#   'id': 968,
#   'network_ability': 1.2853474924971562,
#   'promoted': 1},
#  {'competence': -0.8319702289388012,
#   'id': 969,
#   'network_ability': -0.7392125431772819,
#   'promoted': 0},
#  {'competence': 0.41385036284553606,
#   'id': 970,
#   'network_ability': 1.4766864093055956,
#   'promoted': 1},
#  {'competence': -1.5923725002994595,
#   'id': 971,
#   'network_ability': -0.5438971595163087,
#   'promoted': 0},
#  {'competence': -0.8808546609254152,
#   'id': 972,
#   'network_ability': -0.2076575658788975,
#   'promoted': 0},
#  {'competence': -0.8557718346323623,
#   'id': 973,
#   'network_ability': -0.5058661129076412,
#   'promoted': 0},
#  {'competence': 0.9602839352853884,
#   'id': 974,
#   'network_ability': -0.8975077636441098,
#   'promoted': 0},
#  {'competence': -1.226882710418704,
#   'id': 975,
#   'network_ability': -1.322796662774839,
#   'promoted': 0},
#  {'competence': 0.03829745368539747,
#   'id': 976,
#   'network_ability': -1.0104035221508627,
#   'promoted': 0},
#  {'competence': -1.893660300647853,
#   'id': 977,
#   'network_ability': -0.08041882510568743,
#   'promoted': 0},
#  {'competence': -1.3456736011616104,
#   'id': 978,
#   'network_ability': 0.6549642939555275,
#   'promoted': 0},
#  {'competence': 0.47603042250335476,
#   'id': 979,
#   'network_ability': 0.5788229984994571,
#   'promoted': 0},
#  {'competence': 0.1340487731594767,
#   'id': 980,
#   'network_ability': -0.6581017448308716,
#   'promoted': 0},
#  {'competence': -2.641876309659765,
#   'id': 981,
#   'network_ability': -2.1910221011381847,
#   'promoted': 0},
#  {'competence': -2.897800879358165,
#   'id': 982,
#   'network_ability': -0.6407413850080598,
#   'promoted': 0},
#  {'competence': 2.1047265560754607,
#   'id': 983,
#   'network_ability': -0.4054626019164617,
#   'promoted': 1},
#  {'competence': 0.3865909319597226,
#   'id': 984,
#   'network_ability': -0.394172781512655,
#   'promoted': 0},
#  {'competence': 0.9604680933942096,
#   'id': 985,
#   'network_ability': 0.4723781324109183,
#   'promoted': 0},
#  {'competence': 0.987823718759323,
#   'id': 986,
#   'network_ability': -1.2306522771718675,
#   'promoted': 0},
#  {'competence': 0.03405184772869135,
#   'id': 987,
#   'network_ability': 1.157189586644129,
#   'promoted': 1},
#  {'competence': -0.7733166235639172,
#   'id': 988,
#   'network_ability': 1.5499664140970495,
#   'promoted': 1},
#  {'competence': 0.6360520208977273,
#   'id': 989,
#   'network_ability': -0.4810810352787004,
#   'promoted': 0},
#  {'competence': 1.3273576814692742,
#   'id': 990,
#   'network_ability': -1.0995397275762027,
#   'promoted': 1},
#  {'competence': 0.3954954155016136,
#   'id': 991,
#   'network_ability': -0.3429187766622317,
#   'promoted': 0},
#  {'competence': -1.9616770550411597,
#   'id': 992,
#   'network_ability': 0.8153759223473723,
#   'promoted': 0},
#  {'competence': 0.7419657169285727,
#   'id': 993,
#   'network_ability': -1.3415119030233578,
#   'promoted': 0},
#  {'competence': 1.0502309851849123,
#   'id': 994,
#   'network_ability': 0.5980549019554087,
#   'promoted': 1},
#  {'competence': 0.36698179826295635,
#   'id': 995,
#   'network_ability': -1.574645524730885,
#   'promoted': 0},
#  {'competence': -1.100336906367546,
#   'id': 996,
#   'network_ability': -2.032756177530859,
#   'promoted': 0},
#  {'competence': -1.320859889775283,
#   'id': 997,
#   'network_ability': 0.15745425115042186,
#   'promoted': 0},
#  {'competence': 2.4110773205049716,
#   'id': 998,
#   'network_ability': -0.39059972878696186,
#   'promoted': 1},
#  {'competence': -1.086211608490539,
#   'id': 999,
#   'network_ability': -0.11822893248008305,
#   'promoted': 0}]

# %%
df = pd.DataFrame(dataset)

df
# Out:
#      competence   id  network_ability  promoted
# 0      2.156193    0        -0.138503         1
# 1      0.150321    1         0.680262         0
# 2      0.439139    2         1.076802         1
# 3     -0.515482    3        -0.929916         0
# 4     -0.792828    4         0.238338         0
# ..          ...  ...              ...       ...
# 995    0.366982  995        -1.574646         0
# 996   -1.100337  996        -2.032756         0
# 997   -1.320860  997         0.157454         0
# 998    2.411077  998        -0.390600         1
# 999   -1.086212  999        -0.118229         0
#
# [1000 rows x 4 columns]

# %% [markdown]
# Now we have obtained a pandas dataframe, which is easily analysable with machine elarning modules.

# %% [markdown]
# ## Machine Learning Modelling - Part 1 : Classification Algorithm
#
# Here, the objective to predict the boolean variable `promoted` based on the other variables.
#
# ### Importing Modules and Pre-processing
#
# #### Importing Modules
#
# This time I will be using the `sklearn` module as a basis. I chose sklearn because it is capable from the beginning of the machine learning process all the way to the end. It supports both pre-processing and pipelines, helping me to avoid confusion and potential errors.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# #### Pre-processing - Slicing 'answer 'column
#
# we will have to drop the `promoted` column out of the dataframe as that are the 'solutions' we are trying to figure out. Simultaneously, we will drop the ID column as well, as this is tracked by the index of the dataframe.

# %%
X = df.drop(["promoted", "id"], axis=1)

X
# Out:
#      competence  network_ability
# 0      2.156193        -0.138503
# 1      0.150321         0.680262
# 2      0.439139         1.076802
# 3     -0.515482        -0.929916
# 4     -0.792828         0.238338
# ..          ...              ...
# 995    0.366982        -1.574646
# 996   -1.100337        -2.032756
# 997   -1.320860         0.157454
# 998    2.411077        -0.390600
# 999   -1.086212        -0.118229
#
# [1000 rows x 2 columns]

# %%
X['competence']
# Out:
# 0      2.156193
# 1      0.150321
# 2      0.439139
# 3     -0.515482
# 4     -0.792828
#          ...
# 995    0.366982
# 996   -1.100337
# 997   -1.320860
# 998    2.411077
# 999   -1.086212
# Name: competence, Length: 1000, dtype: float64

# %%
y = df["promoted"]

y
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: promoted, Length: 100000, dtype: int64

# %% [markdown]
# We are left with 2 explanatory variables to determine the result of whether the employee is promoted or not.

# %% [markdown]
# #### Pre-processing - Train Set and Test Set Splitting
#
# I am using the sklearn module to randomly split the dataframe into training set and the test set. I have used a very average ratio of test set of 20%, and I have selected a `random_state` so that the code is replicable.

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %% [markdown]
# ### Pipeline Structuring
#
# I will construct the pipeline in the following way.
#
# 1. Scale the Data down so it is easier to deal with : Using `StandardScaler`.
#
# 2. Apply the classifiers (I will be comparing Ridge Classifier, Logistic Regression, SVC, KNN, and Decision Tree)
#
# 3. Choose the most suitable classifier for the dataset.
#
#
# We will be omitting the PCA, as there are only 2 explanatory variabvles, and it is quite unlikely that one of the varibales is unnecessary.

# %%
pipeline_Ridge = Pipeline([('scale_1', StandardScaler()), ('class_Ridge', RidgeClassifier(random_state=1))])

pipeline_LR = Pipeline([('scale_2', StandardScaler()), ('class_LR', LogisticRegression(random_state=1))])

pipeline_SVC = Pipeline([('scale_3', StandardScaler()), ('class_SVC', SVC(random_state=1))])

pipeline_KNN = Pipeline([('scale_1', StandardScaler()), ('class_KNN', KNeighborsClassifier())])

pipeline_DT = Pipeline([('scale_1', StandardScaler()), ('class_DT', DecisionTreeClassifier(random_state=1))])


pipelines = [pipeline_Ridge, pipeline_LR, pipeline_SVC, pipeline_KNN, pipeline_DT]

# %% [markdown]
# Now the pipelines have been defined, and we will proceed to finding the one with the most accuracy.

# %% [markdown]
# It is always good practice to have a dictionary for each of the classifiers for the later convenience of the codes.

# %%
pipes = {0: 'Ridge Classification', 1: 'Logistic Regression', 2: 'Support Vector Classifier', 3: 'K-Nearest Neighbors CLassification', 4: 'Decision Tree Classification'}

# %% [markdown]
# ### Fitting The Model & Evaluation

# %% [markdown]
# Now we can simply fit the `pipelines`.

# %%
for item in pipelines:
    item.fit(X_train, y_train)

# %% [markdown]
# Now it is time to evaluate how well the models did, thus we will proceed to make the machine "guess" on the test set. The one with highest accuracy is chosen.

# %%
for i, j in enumerate(pipelines):
    print('{} has an accuracy of: {}%.'.format(pipes[i], j.score(X_test,y_test)*100))
# Out:
# Ridge Classification has an accuracy of: 81.635%.
# Logistic Regression has an accuracy of: 81.47999999999999%.
# Support Vector Classifier has an accuracy of: 94.17999999999999%.
# K-Nearest Neighbors CLassification has an accuracy of: 94.69999999999999%.
# Decision Tree Classification has an accuracy of: 90.225%.

# %% [markdown]
# Out of the diverse models chosen, they are quite close to each other, however, **K-Nearest Neighbor** is chosen as the best pipeline out of the 5 models compared. It has an accuracy of **94.7%**.
#
# The hyper-parameter tuning can be done through the pipeline with the following methods:
# (For the most part it is enough to use the Grid search.)
#
# 1. Import GridsearchCV
# 2. create a pipe with classifiers
# 3. create a parameter grids, consulting the different hyperparameters for each classifiers
# 4. Fit the pipe with each parameters on the grid, and assess the accuracy.
#
# In this case we omit this step for the following reasons:
#
# - To keep the work simple
# - The score without hyperparameter tuning is excellent.
# - Avoid overfitting
#
# That said, in practice with high accuracy demand, time resources for making the code clean, and ensurance of overfitting avoidance, it is definitely possible, although it is unsure as to how much it will contribute to the accuracy and the overall effectiveness.

# %% [markdown]
# ## Machine Learning Modelling - Part 2 : Endogenous Variable
